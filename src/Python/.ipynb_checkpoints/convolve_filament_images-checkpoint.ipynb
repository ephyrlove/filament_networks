# %%
import numpy as np
import math as math
import copy
import matplotlib.pyplot as plt
from sklearn import preprocessing 
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import transforms, datasets
import csv
import cv2
import glob
from PIL import Image
from sklearn.model_selection import train_test_split
from scipy.integrate import quad
import sklearn
import codecs, json 
import scipy.io
import h5py
import pandas as pd

device=torch.device("cuda:0")

# Import topnet utilities
import sys
sys.path.insert(0, '/home/ephy/Projects/tda_convolution/src/')
import topnet
import importlib
importlib.reload(topnet)
# Out:
# <module 'topnet' from '/home/ephy/Projects/tda_convolution/src/topnet.py'>

# %%
datadir='/home/ephy/Projects/cytoplasmic_streaming/data/altered/filament_images/filament_images/'

# %%
# Have to get the images in order
nets = []
for i in np.arange(150):
    i=str(i+1)
    file='net'+i+'.png'
    nets.append([cv2.imread(datadir+file, cv2.IMREAD_GRAYSCALE)])

# %%
plt.imshow(nets[1][0],cmap='gray')

# %%
labels = []
for i in range(50):
    labels.append(np.eye(3)[0])
for i in range(50):
    labels.append(np.eye(3)[1])
for i in range(50):
    labels.append(np.eye(3)[2])
labels = np.array(labels,dtype=np.float32)

# %%
train_X , test_X , train_y , test_y = train_test_split(nets , labels, 
                                                test_size = 0.1,
                                                random_state = 1)

# %%
train_y[0]
# Out:
# tensor([1., 0., 0.], device='cuda:0')

# %%
train_X = torch.tensor(train_X,dtype=torch.float).to(device)
train_y = torch.tensor(train_y,dtype=torch.float).to(device)
test_X = torch.tensor(test_X,dtype=torch.float).to(device)
test_y = torch.tensor(test_y,dtype=torch.float).to(device)

# %%
((20-2)**2)
# Out:
# 324

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(1,64,3)
        self.fc1 = nn.Linear(624**2, 500)
        self.fc2 = nn.Linear(500, 3)
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(x.view(-1,624**2))
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.softmax(x, dim=1)

# %%
def test(net):
    with torch.no_grad():
        out = torch.argmax(net(test_X),axis=1)
        return(sum(np.int32((out == torch.argmax(test_y,axis=1)).cpu()))/test_y.shape[0])

# %%
net = Net().to(device)
optimizer = optim.Adam(net.parameters(), lr=1e-3)
batchSize = 1
lossrec=[]
accrec = []
for epoch in range(1):
    for n in range(0, train_X.size()[0], batchSize):
        batch_X = train_X[n:n+batchSize]
        batch_y = train_y[n:n+batchSize]
        net.zero_grad()
        outputs = net(batch_X)
        loss = nn.MSELoss()(outputs, batch_y)
        lossrec.append(loss.tolist())
        loss.backward()
        optimizer.step()
        if n%1000==0:
            accrec.append(test(net))
# Out:
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 0., 1.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# tensor([[1., 0., 0.]], device='cuda:0')
# tensor([[0., 1., 0.]], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-ea8d0d59fe2a> in <module>
#      10         net.zero_grad()
#      11         outputs = net(batch_X)
# ---> 12         print(batch_y)
#      13         loss = nn.MSELoss()(outputs, batch_y)
#      14         lossrec.append(loss.tolist())
#
# ~/anaconda3/envs/opencvenv/lib/python3.7/site-packages/torch/tensor.py in __repr__(self)
#     128         # characters to replace unicode characters with.
#     129         if sys.version_info > (3,):
# --> 130             return torch._tensor_str._str(self)
#     131         else:
#     132             if hasattr(sys.stdout, 'encoding'):
#
# ~/anaconda3/envs/opencvenv/lib/python3.7/site-packages/torch/_tensor_str.py in _str(self)
#     309                 tensor_str = _tensor_str(self.to_dense(), indent)
#     310             else:
# --> 311                 tensor_str = _tensor_str(self, indent)
#     312
#     313     if self.layout != torch.strided:
#
# ~/anaconda3/envs/opencvenv/lib/python3.7/site-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     207     if self.dtype is torch.float16 or self.dtype is torch.bfloat16:
#     208         self = self.float()
# --> 209     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     210     return _tensor_str_with_formatter(self, indent, formatter, summarize)
#     211
#
# ~/anaconda3/envs/opencvenv/lib/python3.7/site-packages/torch/_tensor_str.py in __init__(self, tensor)
#      85
#      86         else:
# ---> 87             nonzero_finite_vals = torch.masked_select(tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0))
#      88
#      89             if nonzero_finite_vals.numel() == 0:
#
# KeyboardInterrupt:

# %%
plt.plot(accrec)

# %%
np.sqrt(389376)
# Out:
# 624.0
